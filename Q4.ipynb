# %%
l=[1,2,3,4,5,"kalpesh",78,[12,23,45],98.20,78,True]

# %%
l=[1,2,3,4,5,"kalpesh",78,[12,23,45],98.20,78,True]
for i in l:
  print(type(i))
  if i==0:
     continue
  print(i)
# Out:
# <class 'int'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# 3
# <class 'int'>
# 4
# <class 'int'>
# 5
# <class 'str'>
# kalpesh
# <class 'int'>
# 78
# <class 'list'>
# [12, 23, 45]
# <class 'float'>
# 98.2
# <class 'int'>
# 78
# <class 'bool'>
# True
