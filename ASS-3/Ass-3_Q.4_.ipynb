# %% [markdown]
# Q4. What is a generator function in python? Why yield keyword is used? Give an example of a generator
# function.

# %% [markdown]
# => generator function allows you to declare a function that behaves like an iterator, providing a faster and easier way to create iterators. They can be used on an abstract container of data to turn it into an iterable object like lists,
# => The yield expressions return multiple value

# %%
def gen_fuc(x):
  for i in range(x):
    yield i

# %%
gen_fuc(10)
# Out:
# <generator object gen_fuc at 0x7fe8245e3290>
