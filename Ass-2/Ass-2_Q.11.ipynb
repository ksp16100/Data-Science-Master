# %%
is_student = True
if is_student == True:
  print("student")
else:
  print("not student")
# Out:
# student

# %%
=================================================

# %%
is_student = False
if is_student == True:
  print("student")
else:
  print("not student")
# Out:
# not student
