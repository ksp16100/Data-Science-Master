# %% [markdown]
# #Nine types of varieble is it 1-int, 2-str, 3-bool, 4-float, -complex, -list, 7-tupal, 8-set, 9-dict

# %%
a=12
a
# Out:
# 12

# %%
type(a)
# Out:
# int

# %%
============================================

# %%
b= "kalpesh"
b
# Out:
# 'kalpesh'

# %%
type(b)
# Out:
# str

# %%
===================================================

# %%
c= True
c
# Out:
# True

# %%
type(c)
# Out:
# bool

# %%
==================================================================================

# %%
d=12.33
d
# Out:
# 12.33

# %%
type(d)
# Out:
# float

# %%
===========================================================================

# %%
e = 8 + 9j

# %%
type(e)
# Out:
# complex

# %%
e.imag
# Out:
# 9.0

# %%
e.real
# Out:
# 8.0

# %%
===================================================================

# %%
l=["kalpesh","patil","vijay","mkb",1 ,23,36,36,34,38,30,8]

# %%
l
# Out:
# ['kalpesh', 'patil', 'vijay', 'mkb', 1, 23, 36, 36, 34, 38, 30, 8]

# %%
type(l)
# Out:
# list

# %%
===================================================================

# %%
t = (1,2,3,4,"kalpesh",True,False)

# %%
t
# Out:
# (1, 2, 3, 4, 'kalpesh', True, False)

# %%
type(t)
# Out:
# tuple

# %%
=========================================================

# %%
dict= {'a':"orange",'b':"mango",'c':"banana"}

# %%
dict
# Out:
# {'a': 'orange', 'b': 'mango', 'c': 'banana'}

# %%
type(dict)
# Out:
# dict

# %%
===================================================================

# %%
s1= {"apple", "banana", "cherry"}

# %%
type(s1)
# Out:
# set

# %%
====================================================
