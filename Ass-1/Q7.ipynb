# %%
l=[1,2,3,4,5,67,7,9,"kalpesh","patil"]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 67, 7, 9, 'kalpesh', 'patil']

# %%
l[0]
# Out:
# 1

# %%
l[3]="ksp"

# %%
l ##list  is mutable
# Out:
# [1, 2, 3, 'ksp', 5, 67, 7, 9, 'kalpesh', 'patil']

# %%
type(l)
# Out:
# list

# %%
p="kalpesh"

# %%
p
# Out:
# 'kalpesh'

# %%
p[3]='l'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d9a16d0464ba> in <cell line: 1>()
# ----> 1 p[3]='l'
#
# TypeError: 'str' object does not support item assignment

# %%
type(p) ## string is inmutabl
# Out:
# str
