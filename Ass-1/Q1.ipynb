# %%
x="kalpesh="
x
# Out:
# 'kalpesh='

# %%
================================================================================

# %%
l=[1,2,3,4,5,"kalpesh",78,[12,23,45],98,78]
l
# Out:
# [1, 2, 3, 4, 5, 'kalpesh', 78, [12, 23, 45], 98, 78]

# %%
l[7]
# Out:
# [12, 23, 45]

# %%
=======================================================================

# %%
t=5.6
y=8.7
t+y
# Out:
# 14.299999999999999

# %%
=======================================================================================

# %%
l=[5,63,"patil",76,78,98]

# %%
l
# Out:
# [5, 63, 'patil', 76, 78, 98]

# %%
=====================================================================================
