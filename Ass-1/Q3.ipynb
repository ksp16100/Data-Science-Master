# %%
k=9
p=3
k / p # used of division
# Out:
# 3.0

# %%
X=7
Y=2
X % Y # used of Modulus
# Out:
# 1

# %%
j=13
k=2
j // k  # the floor division // rounds the result down to the nearest whole number
# Out:
# 6

# %%
m=3
n=2
m ** n # used of Exponentiation
# Out:
# 9
