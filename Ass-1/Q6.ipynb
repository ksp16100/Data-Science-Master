# %%
l=[12,13,14,13,23,34,35,46,48,59,23,45,23,22,11,45,66,77,88,99,66,55,16,14,17]
for i in l:
  print(i)
  if i%3==0:
    print("it is divisible")
  else:
    print("it is not divisible")
# Out:
# 12
# it is divisible
# 13
# it is not divisible
# 14
# it is not divisible
# 13
# it is not divisible
# 23
# it is not divisible
# 34
# it is not divisible
# 35
# it is not divisible
# 46
# it is not divisible
# 48
# it is divisible
# 59
# it is not divisible
# 23
# it is not divisible
# 45
# it is divisible
# 23
# it is not divisible
# 22
# it is not divisible
# 11
# it is not divisible
# 45
# it is divisible
# 66
# it is divisible
# 77
# it is not divisible
# 88
# it is not divisible
# 99
# it is divisible
# 66
# it is divisible
# 55
# it is not divisible
# 16
# it is not divisible
# 14
# it is not divisible
# 17
# it is not divisible

# %%
l=[range(25)]

# %%
l
print(l)
# Out:
# [range(0, 25)]
